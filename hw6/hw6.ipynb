# %% [markdown]
# ## Reference: https://github.com/lucidrains/stylegan2-pytorch
# ## Train Step
# 1. create  "hw6" folder in "Colab Notebook" folder in google drive
# 2. upload "archive.zip" in "hw6" folder as the dataset and unzip it (the dataset provide by TA)
# 3. start training

# %%
# !pip install stylegan2_pytorch
# !pip install pytorch-fid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 82.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.1/628.1 kB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 66.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 76.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# %cd drive
# Out:
# drive  sample_data
# /content/drive

# %%
# !ls MyDrive/Colab\ Notebooks/hw6
# %cd MyDrive/Colab\ Notebooks/hw6
# Out:
# archive.zip  faces  hw6.ipynb  models  results
# /content/drive/MyDrive/Colab Notebooks/hw6

# %%
# !ls
# !unzip archive.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: faces/faces/69681.jpg
#   inflating: faces/faces/69682.jpg
#   inflating: faces/faces/69683.jpg
#   inflating: faces/faces/69684.jpg
#   inflating: faces/faces/69685.jpg
#   inflating: faces/faces/69686.jpg
#   inflating: faces/faces/69687.jpg
#   inflating: faces/faces/69688.jpg
#   inflating: faces/faces/69689.jpg
#   inflating: faces/faces/6969.jpg
#   inflating: faces/faces/69690.jpg
#   inflating: faces/faces/69691.jpg
#   inflating: faces/faces/69692.jpg
#   inflating: faces/faces/69693.jpg
#   inflating: faces/faces/69694.jpg
#   inflating: faces/faces/69695.jpg
#   inflating: faces/faces/69696.jpg
#   inflating: faces/faces/69697.jpg
#   inflating: faces/faces/69698.jpg
#   inflating: faces/faces/69699.jpg
#   inflating: faces/faces/697.jpg
#   inflating: faces/faces/6970.jpg
#   inflating: faces/faces/69700.jpg
#   inflating: faces/faces/69701.jpg
#   inflating: faces/faces/69702.jpg
#   inflating: faces/faces/69703.jpg
# ...

# %%
# %cd ..
import os
# !ls ./models/default
# !stylegan2_pytorch --data ./faces/faces --image-size 64 --batch-size 64 --num-train-steps=10000 --top-k-training --attn-layers [1,2,5,8]
# Out:
# model_5.pt
# continuing from previous epoch - 5
# loading from version 1.8.9
# default<./faces/faces>:  50% 5008/10000 [00:53<9:20:25,  6.74s/it]

# %%
import os
temp_file = os.listdir("./results/default")
length = len(temp_file)
for i in range (0,length):
  os.remove("./results/default/"+temp_file[i])

# %%
# !stylegan2_pytorch --generate --num_generate=1000 --num_image_tiles=1 --trunc-psi 0.85
# !ls ./results/default
# Out:
# continuing from previous epoch - 5
# loading from version 1.8.9
# 100% 1000/1000 [00:44<00:00, 22.61it/s]
# sample images generated at ./results/default/generated-04-20-2023_18-56-50
# generated-04-20-2023_18-56-50-0-ema.jpg
# generated-04-20-2023_18-56-50-0.jpg
# generated-04-20-2023_18-56-50-0-mr.jpg
# generated-04-20-2023_18-56-50-100-ema.jpg
# generated-04-20-2023_18-56-50-100.jpg
# generated-04-20-2023_18-56-50-100-mr.jpg
# generated-04-20-2023_18-56-50-101-ema.jpg
# generated-04-20-2023_18-56-50-101.jpg
# generated-04-20-2023_18-56-50-101-mr.jpg
# generated-04-20-2023_18-56-50-102-ema.jpg
# generated-04-20-2023_18-56-50-102.jpg
# generated-04-20-2023_18-56-50-102-mr.jpg
# generated-04-20-2023_18-56-50-103-ema.jpg
# generated-04-20-2023_18-56-50-103.jpg
# generated-04-20-2023_18-56-50-103-mr.jpg
# generated-04-20-2023_18-56-50-104-ema.jpg
# generated-04-20-2023_18-56-50-104.jpg
# generated-04-20-2023_18-56-50-104-mr.jpg
# generated-04-20-2023_18-56-50-105-ema.jpg
# ...

# %%
all_file_name = os.listdir("./results/default/")
length1 = len(all_file_name)
print(length1)
# Out:
# 3000

# %%
# !ls ./results/default/
# Out:
# generated-04-20-2023_18-56-50-0-ema.jpg
# generated-04-20-2023_18-56-50-0.jpg
# generated-04-20-2023_18-56-50-0-mr.jpg
# generated-04-20-2023_18-56-50-100-ema.jpg
# generated-04-20-2023_18-56-50-100.jpg
# generated-04-20-2023_18-56-50-100-mr.jpg
# generated-04-20-2023_18-56-50-101-ema.jpg
# generated-04-20-2023_18-56-50-101.jpg
# generated-04-20-2023_18-56-50-101-mr.jpg
# generated-04-20-2023_18-56-50-102-ema.jpg
# generated-04-20-2023_18-56-50-102.jpg
# generated-04-20-2023_18-56-50-102-mr.jpg
# generated-04-20-2023_18-56-50-103-ema.jpg
# generated-04-20-2023_18-56-50-103.jpg
# generated-04-20-2023_18-56-50-103-mr.jpg
# generated-04-20-2023_18-56-50-104-ema.jpg
# generated-04-20-2023_18-56-50-104.jpg
# generated-04-20-2023_18-56-50-104-mr.jpg
# generated-04-20-2023_18-56-50-105-ema.jpg
# generated-04-20-2023_18-56-50-105.jpg
# generated-04-20-2023_18-56-50-105-mr.jpg
# generated-04-20-2023_18-56-50-106-ema.jpg
# generated-04-20-2023_18-56-50-106.jpg
# ...

# %%
for i in range (0,length1):
    if i%3 == 0:
        os.rename("./results/default/"+all_file_name[i], "./results/default/"+ str(i//3)+".jpg")
    else:
        os.remove("./results/default/"+all_file_name[i])
# %cd ./results/default
# !tar -zcf ../submission.tgz *.jpg
# %cd ../..
# Out:
# /content/drive/MyDrive/Colab Notebooks/hw6/results/default
# /content/drive/MyDrive/Colab Notebooks/hw6
